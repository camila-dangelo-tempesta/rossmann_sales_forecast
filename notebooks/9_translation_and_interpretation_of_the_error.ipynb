# %% [markdown]
# # 0.0 IMPORTS

# %%
import math
import pickle
import random
import datetime
import numpy             as np
import pandas            as pd
import inflection
import seaborn           as sns
import matplotlib 
import matplotlib.pyplot as plt
import xgboost           as xgb
import warnings

from scipy                          import stats as ss
from boruta                         import BorutaPy
from tabulate                       import tabulate
from IPython.display                import Image
from IPython.core.display           import HTML
from  matplotlib.gridspec           import GridSpec

from sklearn.preprocessing          import LabelEncoder
from sklearn.ensemble               import RandomForestRegressor
from sklearn.linear_model           import LinearRegression, Lasso
from sklearn.preprocessing          import RobustScaler, MinMaxScaler
from sklearn.metrics                import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    sns.set()

# %%
jupyter_settings()

# %%
def cramer_v(x,y):
    cm = pd.crosstab(x,y).values
    n= cm.sum()
    r, k= cm.shape
    
    chi2 = ss.chi2_contingency(cm)[0]
    chi2corr = max(0, chi2 - (k-1)*(r-1)/(n-1))
    
    kcorr = k -(k-1)**2/(n-1)
    rcorr = r -(r-1)**2/(n-1)
    
    return np.sqrt((chi2corr/n) / ( min( kcorr-1, rcorr-1) ) )

# %%
def cross_validation(x_training, kfold, model_name, model, verbose=False):
    mae_list = []
    mape_list = []
    rmse_list = []

    # start and end date for validation
    for k in reversed(range(1,kfold+1)):
        if verbose:
            print('KFold Number: {}'.format(k))
        validation_start_date = x_training['date'].max() - datetime.timedelta(days=k*6*7)
        validation_end_date = x_training['date'].max() - datetime.timedelta(days=(k-1)*6*7)

        #filtering dataset
        training = x_training[x_training['date']<validation_start_date]
        validation = x_training[(x_training['date']>=validation_start_date) & (x_training['date']<=validation_end_date)]

        #training and validation dataset
        xtraining = training.drop(['date', 'sales'], axis=1)
        ytraining = training['sales']

        xvalidation =validation.drop(['date', 'sales'], axis=1)
        yvalidation = validation['sales']

        #model
        m = model.fit(xtraining, ytraining)

        #prediction
        yhat = m.predict(xvalidation)

        #performance
        m_result = ml_error(model_name, np.expm1(yvalidation), np.expm1(yhat))

        #store performance of each kfold iteration
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])

    return pd.DataFrame({'Model Name': model_name,
                         'MAE CV': np.round(np.mean(mae_list),2).astype(str)  + ' +/- ' + np.round(np.std(mae_list),2).astype(str),
                         'MAPE CV': np.round(np.mean(mape_list),2).astype(str)  + ' +/- ' + np.round(np.std(mape_list),2).astype(str),
                         'RMSE CV': np.round(np.mean(rmse_list),2).astype(str)  + ' +/- ' + np.round(np.std(rmse_list),2).astype(str),}, index=[0])

# %%
def mean_absolute_percentage_error(y, yhat):
    return np.mean(np.abs((y - yhat) / y))


def mean_percentage_error(y, yhat):
    return np.mean((y - yhat)/y)


def ml_error(model_name, y, yhat):
    mae = mean_absolute_error(y, yhat)
    mape = mean_absolute_percentage_error(y, yhat)
    rmse = np.sqrt(mean_squared_error(y, yhat))
    
    return pd.DataFrame({'Model Name': model_name,
                         'MAE'       : mae,
                         'MAPE'      : mape,
                         'RMSE'      : rmse}, index=[0])

# %%
# Notação Científica
np.set_printoptions(suppress=True)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ## LOADING DATA

# %%
df_sales_raw = pd.read_csv('C:/Users/Utilizador/repos/Data_Science_em_Producao/data/train.csv', low_memory=False)
df_store_raw = pd.read_csv('C:/Users/Utilizador/repos/Data_Science_em_Producao/data/store.csv', low_memory=False)

# Merge
df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store')
df_raw.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a              1270.00
# 1              1         a          a               570.00
# 2              1         a          a             14130.00
# 3              1         c          c               620.00
# 4              1         a          a             29910.00
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                       9.00                   2008.00       0
# ...

# %% [markdown]
# # 1.0 DATA CLEANING

# %% [markdown]
# ## Data Description

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename Columns

# %%
cols_old = ['Store', 
            'DayOfWeek', 
            'Date', 
            'Sales', 
            'Customers', 
            'Open', 
            'Promo',
            'StateHoliday', 
            'SchoolHoliday', 
            'StoreType', 
            'Assortment',
            'CompetitionDistance', 
            'CompetitionOpenSinceMonth',
            'CompetitionOpenSinceYear', 
            'Promo2', 
            'Promo2SinceWeek',
            'Promo2SinceYear', 
            'PromoInterval']

snakecase = lambda x: inflection.underscore(x)

cols_new = list(map(snakecase, cols_old))

# Rename
df1.columns = cols_new
df1.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'customers', 'open', 'promo',
#        'state_holiday', 'school_holiday', 'store_type', 'assortment',
#        'competition_distance', 'competition_open_since_month',
#        'competition_open_since_year', 'promo2', 'promo2_since_week',
#        'promo2_since_year', 'promo_interval'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Cols: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# store                             int64
# day_of_week                       int64
# date                             object
# sales                             int64
# customers                         int64
# open                              int64
# promo                             int64
# state_holiday                    object
# school_holiday                    int64
# store_type                       object
# assortment                       object
# competition_distance            float64
# competition_open_since_month    float64
# competition_open_since_year     float64
# promo2                            int64
# promo2_since_week               float64
# promo2_since_year               float64
# promo_interval                   object
# dtype: object

# %%
df1['date'] = pd.to_datetime(df1['date'])

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %%
# percentage of missing data by total rows
df1.isna().sum() / df1.shape[0]
# Out:
# store                          0.00
# day_of_week                    0.00
# date                           0.00
# sales                          0.00
# customers                      0.00
# open                           0.00
# promo                          0.00
# state_holiday                  0.00
# school_holiday                 0.00
# store_type                     0.00
# assortment                     0.00
# competition_distance           0.00
# competition_open_since_month   0.32
# competition_open_since_year    0.32
# promo2                         0.00
# promo2_since_week              0.50
# promo2_since_year              0.50
# promo_interval                 0.50
# dtype: float64

# %% [markdown]
# ## 1.5 Fillout NA ():
# Preencher NA
#
# Formas de se fazer:
# - exclui-las
# - Machine Learning: input de na (substituir os na pela média por exemplo)
# - Entendendo o negócio: lógica do negócio

# %%
# competition_distance: distance in meters to the nearest competitor store 
# Definição:  distância em metros até a loja concorrente mais próxima;
# Porque temos NA: podemos entender ue não há uma loja perto, ou a loja está tão longe que não oferece uma competição, ou seja não cobre os mesmos clientes
# Estratégia: vamos substituir os NA por uma valor muito maior que o máximo(75860.0) da coluna competition_distance

# Então temos 75860 metros de distância até o competidor(loja) mais próxima
df1['competition_distance'].max()

df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)

# %%
# competition_open_since_month: gives the approximate year and month of the time the nearest competitor was opened
# Definição:  fornece o mês aproximados da hora em que o concorrente mais próximo foi aberto;
# Porque temos NA:1º: A loja não tem competidor mais próximo, sendo assim não temos uma data de abertura,
#                 2º: Existe uma loja, mas não sabemos quando abriu. Porque tem uma data muito antiga, ou perdeu se essa informação
# Estratégia: Vamos fazer uma cópia das informações (mês) da coluna date para competition_open_since_month

df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month 
                                                if math.isnan(x['competition_open_since_month']) 
                                                else x['competition_open_since_month'], axis=1)

# %%
# competition_open_since_year: gives the approximate year and month of the time the nearest competitor was opened
# Definição:  fornece o ano aproximados da hora em que o concorrente mais próximo foi aberto;
# Porque temos NA:1º: A loja não tem competidor mais próximo, sendo assim não temos uma data de abertura,
#                 2º: Existe uma loja, mas não sabemos quando abriu. Porque tem uma data muito antiga, ou perdeu se essa informação
# Estratégia: Vamos fazer uma cópia das informações (ano) da coluna date para a coluna competition_open_since_year


df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year
                                                if math.isnan(x['competition_open_since_year']) 
                                                else x['competition_open_since_year'], axis=1)

# %%
# promo2_since_week: describes the year and calendar week when the store started participating in Promo2
# Definição: descreve a semana do calendário em que a loja começou a participar do Promo2(continuação de uma promoção);
# Porque temos NA: A loja decidiu não participar da continuação da promoção,
# Estratégia: Vamos fazer uma cópia das informações (semana) da coluna date para a coluna promo2_since_week


df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week
                                                if math.isnan(x['promo2_since_week']) 
                                                else x['promo2_since_week'], axis=1)

# %%
# promo2_since_year: describes the year and calendar week when the store started participating in Promo2
# Definição: descreve o ano do calendário em que a loja começou a participar do Promo2(continuação de uma promoção);
# Porque temos NA: A loja decidiu não participar da continuação da promoção,
# Estratégia: Vamos fazer uma cópia das informações (ano) da coluna date para a coluna promo2_since_year

df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year
                                                if math.isnan(x['promo2_since_year']) 
                                                else x['promo2_since_year'], axis=1)

# %%
# promo_interval: describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store
# Definição: descreve os intervalos consecutivos em que a Promo2 é iniciada, nomeando os meses em que a promoção é iniciada novamente. Por exemplo. "fev, maio, agosto, novembro" significa que cada rodada começa em fevereiro, maio, agosto, novembro de qualquer ano para essa loja;
# Porque temos NA: A loja decidiu não participar da continuação da promoção,
# Estratégia: Vamos criar uma nova coluna,  com indicação de Ativo, ou seja, a promo2 foi continuada. Caso a coluna data esteje preenchida.

# Criando dicionário que faz a troca do número do mês pelo nome do mês
month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sept', 10: 'Oct', 11: 'Nov', 12: 'Dec', }

# Substituindo os NA por 0 na coluna promo_interval
df1['promo_interval'].fillna(0, inplace=True)

# Criando nova coluna(month_map) que recebe o mês estraido da coluna date a aplica-se o dicionário para fazer a comparação
df1['month_map'] = df1['date'].dt.month.map(month_map)

# Criando uma nova coluna(is_promo) que recebe 0 ou 1 dependendo da regra de negócio(promo_interval). Ou , se o meu month_map está dentro do intervalo do promo_interval
df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split(',') else 0, axis=1)

# %%
# Olhar os dados
df1.sample()
# Out:
#         store  day_of_week       date  sales  customers  open  promo  \
# 698178    974            1 2013-10-14  10440       1538     1      0
#
#        state_holiday  school_holiday store_type assortment  \
# 698178             0               0          a          a
#
#         competition_distance  competition_open_since_month  \
# 698178                150.00                          3.00
#
#         competition_open_since_year  promo2  promo2_since_week  \
# 698178                      2011.00       1              40.00
#
#         promo2_since_year   promo_interval month_map  is_promo
# 698178            2014.00  Jan,Apr,Jul,Oct       Oct         1

# %%
# Checando se eliminamos os NA
df1.isna().sum() / df1.shape[0]
# Out:
# store                          0.00
# day_of_week                    0.00
# date                           0.00
# sales                          0.00
# customers                      0.00
# open                           0.00
# promo                          0.00
# state_holiday                  0.00
# school_holiday                 0.00
# store_type                     0.00
# assortment                     0.00
# competition_distance           0.00
# competition_open_since_month   0.00
# competition_open_since_year    0.00
# promo2                         0.00
# promo2_since_week              0.00
# promo2_since_year              0.00
# promo_interval                 0.00
# month_map                      0.00
# is_promo                       0.00
# dtype: float64

# %% [markdown]
# ## 1.6 Change Types

# %%
# Após tranformações devemos checar novamente os tipos das colunas
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype('int64')
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype('int64')
df1['promo2_since_week'] = df1['promo2_since_week'].astype('int64')
df1['promo2_since_year'] = df1['promo2_since_year'].astype('int64')

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %% [markdown]
# ## 1.7 Descriptive Statistical
#
# Métricas de dispersão e tendência central
#
# - Ganhar conhecimento de negócio
# - Detectar erros

# %%
num_attributes = df1.select_dtypes(include=['int64','float64' ])
num_attributes
# Out:
#          store  day_of_week  sales  customers  open  promo  school_holiday  \
# 0            1            5   5263        555     1      1               1
# 1            2            5   6064        625     1      1               1
# 2            3            5   8314        821     1      1               1
# 3            4            5  13995       1498     1      1               1
# 4            5            5   4822        559     1      1               1
# ...        ...          ...    ...        ...   ...    ...             ...
# 1017204   1111            2      0          0     0      0               1
# 1017205   1112            2      0          0     0      0               1
# 1017206   1113            2      0          0     0      0               1
# 1017207   1114            2      0          0     0      0               1
# 1017208   1115            2      0          0     0      0               1
#
#          competition_distance  competition_open_since_month  \
# ...

# %%
cat_attributes = df1.select_dtypes(exclude=['int64','float64', 'datetime64[ns]'])
cat_attributes
# Out:
#         state_holiday store_type assortment    promo_interval month_map
# 0                   0          c          a                 0       Jul
# 1                   0          a          a   Jan,Apr,Jul,Oct       Jul
# 2                   0          a          a   Jan,Apr,Jul,Oct       Jul
# 3                   0          c          c                 0       Jul
# 4                   0          a          a                 0       Jul
# ...               ...        ...        ...               ...       ...
# 1017204             a          a          a   Jan,Apr,Jul,Oct       Jan
# 1017205             a          c          c                 0       Jan
# 1017206             a          a          c                 0       Jan
# 1017207             a          a          c                 0       Jan
# 1017208             a          d          c  Mar,Jun,Sept,Dec       Jan
#
# [1017209 rows x 5 columns]

# %%
num_attributes.sample(2)
# Out:
#         store  day_of_week  sales  customers  open  promo  school_holiday  \
# 760303    659            1   4141        594     1      0               0
# 306596    109            5   4983        630     1      0               1
#
#         competition_distance  competition_open_since_month  \
# 760303               1590.00                             3
# 306596               3300.00                            11
#
#         competition_open_since_year  promo2  promo2_since_week  \
# 760303                         2012       0                 34
# 306596                         2010       0                 42
#
#         promo2_since_year  is_promo
# 760303               2013         0
# 306596               2014         0

# %%
cat_attributes.sample(2)
# Out:
#        state_holiday store_type assortment promo_interval month_map
# 868676             0          a          c              0       May
# 195423             0          d          c              0       Feb

# %% [markdown]
# ## 1.7.1 Numerical Attributes

# %%
# Tendência centra: como os dados estão :

# Média
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T

# Mediana
ct2= pd.DataFrame(num_attributes.apply(np.median)).T

# %%
# Dispersão: std, min, max, range, skew(assimetria), kurtosis(calda longa)

d1 = pd.DataFrame(num_attributes.apply(np.std)).T

d2 = pd.DataFrame(num_attributes.apply(np.min)).T

d3 = pd.DataFrame(num_attributes.apply(np.max)).T

d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T

d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T

d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# %%
# concat

m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes','min','max','range','mean','median','std','skew','kurtosis']
m
# Out:
#                       attributes     min       max     range    mean  median  \
# 0                          store    1.00   1115.00   1114.00  558.43  558.00
# 1                    day_of_week    1.00      7.00      6.00    4.00    4.00
# 2                          sales    0.00  41551.00  41551.00 5773.82 5744.00
# 3                      customers    0.00   7388.00   7388.00  633.15  609.00
# 4                           open    0.00      1.00      1.00    0.83    1.00
# 5                          promo    0.00      1.00      1.00    0.38    0.00
# 6                 school_holiday    0.00      1.00      1.00    0.18    0.00
# 7           competition_distance   20.00 200000.00 199980.00 5935.44 2330.00
# 8   competition_open_since_month    1.00     12.00     11.00    6.79    7.00
# 9    competition_open_since_year 1900.00   2015.00    115.00 2010.32 2012.00
# 10                        promo2    0.00      1.00      1.00    0.50    1.00
# ...

# %%
sns.distplot(df1['sales']);
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,6))
sns.distplot(df1['sales'], kde=False)
plt.title('Distribution of sales');
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Outra forma de plotar
sns.displot(df1['sales']);

# %%
sns.distplot(df1['competition_distance']);
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Outra forma de plotar
sns.displot(df1['competition_distance']);

# %% [markdown]
# ## 1.7.2 Categorical Attributes

# %%
# Tipo unicos das variaveis categoricas por coluna
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
# Boxplot
# Tracinho em cima: valor máximo (Q3+1.5*(Q3-Q1). Tudo qu está acima (pontos acima do tracinho) é outlier(3xdesviopadrão)
# Tracinho em baixo: valor minimo (Q1 - 1.5*(Q3-Q1))
# Linha até o tracinho: (volume dos dados do quartil 75 até 100)
# Linha de cima: 75º quartil (volume dos dados do quartil 50 até 75)
# Linha do meio: Mediana (volume dos dados do quartil )
# Linha de baixo: 25ª  (volume dos dados do quartil 25 até 50)


aux1 = df1[(df1['state_holiday'] != '0') & (df1['sales'] > 0)]

plt.subplot(1,3,1)
sns.boxplot(x='state_holiday', y='sales', data=aux1)

plt.subplot(1,3,2)
sns.boxplot(x='store_type', y='sales', data=aux1)

plt.subplot(1,3,3)
sns.boxplot(x='assortment', y='sales', data=aux1);

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Hypoteses Mind map

# %%
Image('C:/Users/Utilizador/repos/Data_Science_em_Producao/img/Mindmap.png')

# %% [markdown]
# Ex: Lojas de maior porte deveriam vender mais;
# - Aposta: maior/mais
#     - Atributos: porte(tamanho da loja)
#         - Variavel resposta: vender
#
# Ex: Lojas com maior sortimento deveriam vender mais;
# - Aposta: maior/mais
#     - Atributos: sortimento(produtos)
#         - Variavel resposta: vender
#
# Ex: Lojas com mais competidores por perto deveriam vender menos;
# - Aposta: mais/menos
#     - Atributos: competidores por perto
#         - Variavel resposta: vender

# %% [markdown]
# ## 2.2 Criação de Hipoteses

# %% [markdown]
# ### 2.2.1 Hipoteses: LOJA

# %% [markdown]
# 1. Lojas com número maior de funcionários deveriam vender mais. (ainda não tenho dados)
# 2. Lojas com maior capacidade de estoque deveriam vender mais. (ainda não tenho dados)
# 3. Lojas com maior porte deveriam vender mais. (ainda não tenho dados)
# 4. Lojas com maior sortimentos deveriam vender mais. ok
# 5. Lojas com competidores mais próximos deveriam vender menos. ok
# 6. Lojas com competidores à mais tempo deveriam vendem mais. ok

# %% [markdown]
# ### 2.2.2 Hipoteses: PRODUTO

# %% [markdown]
# 1. Lojas que investem mais em Marketing deveriam vender mais. (ainda não tenho dados)
# 2. Lojas com maior exposição de produto deveriam vender mais. (ainda não tenho dados)
# 3. Lojas com produtos com preço menor deveriam vender mais. (ainda não tenho dados)
# 5. Lojas com promoções mais agressivas ( descontos maiores ), deveriam vender mais. (ainda não tenho dados)
# 6. Lojas com promoções ativas por mais tempo deveriam vender mais. ok
# 7. Lojas com mais dias de promoção deveriam vender mais. ok
# 8. Lojas com mais promoções consecutivas deveriam vender mais. ok

# %% [markdown]
# ### 2.2.2 Hipoteses: TEMPO

# %% [markdown]
# 1. Lojas abertas durante o feriado de Natal deveriam vender mais. ok
# 2. Lojas deveriam vender mais ao longo dos anos. ok
# 3. Lojas deveriam vender mais no segundo semestre do ano. ok
# 4. Lojas deveriam vender mais depois do dia 10 de cada mês. ok
# 5. Lojas deveriam vender menos aos finais de semana. ok
# 6. Lojas deveriam vender menos durante os feriados escolares. ok

# %% [markdown]
# ## Lista Final de Hipóteses

# %% [markdown]
# 1. Lojas com maior sortimentos deveriam vender mais.
# 2. Lojas com competidores mais próximos deveriam vender menos.
# 3. Lojas com competidores à mais tempo deveriam vendem mais.
# 4. Lojas com promoções ativas por mais tempo deveriam vender mais.
# 5. Lojas com mais dias de promoção deveriam vender mais.
# 6. Lojas com mais promoções consecutivas deveriam vender mais.
# 7. Lojas abertas durante o feriado de Natal deveriam vender mais.
# 8. Lojas deveriam vender mais ao longo dos anos.
# 9. Lojas deveriam vender mais no segundo semestre do ano.
# 10. Lojas deveriam vender mais depois do dia 10 de cada mês.
# 11. Lojas deveriam vender menos aos finais de semana.
# 12. Lojas deveriam vender menos durante os feriados escolares

# %% [markdown]
# ## 2.3 Feature Engineering: derivando as variaveis

# %%
# year
df2['year'] = df2['date'].dt.year

# month
df2['month'] = df2['date'].dt.month

# day
df2['day'] = df2['date'].dt.day

# week of year
df2['week_of_year'] = df2['date'].dt.weekofyear

# year week
df2['year_week'] = df2['date'].dt.strftime( '%Y-%W' )
# Out:
# C:\Users\UTILIZ~1\AppData\Local\Temp/ipykernel_15016/2268827306.py:11: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2['week_of_year'] = df2['date'].dt.weekofyear

# %%
# Nova fórmula a ser usada na conversão week for year
df2['week_of_year'] = df2['date'].dt.isocalendar().week

# %%
# competition since: tempo entre duas datas

# Juntar competition_open_since_year and competition_open_since_month em uma nova coluna competition_since
df2['competition_since'] = df2.apply( lambda x: datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'],day=1 ), axis=1 )

# Fazer a diferença entre duas colunas: date - competition_since e atribuir a uma nova coluna: competition_time_month
df2['competition_time_month'] = ( ( df2['date'] - df2['competition_since'] )/30).apply( lambda x: x.days ).astype( int )

# %%
# promo since: tempo entre duas datas

# Join dos caracteres para depois fazer a data
df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )

# Convertendo a coluna promo_since(string) em datetime e tranformando os dias em semanas
df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta( days=7 ) )

# Fazer a diferença entre duas colunas: date - promo_since e atribuir a uma nova coluna: promo_time_week
df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since'] )/7 ).apply(lambda x: x.days ).astype( int )

# %%
# assortment: troca das letras pelo texto a, b, c pelos seus respectivos textos
df2['assortment'] = df2['assortment'].apply( lambda x: 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )

# %%
# state holiday: troca das letras a, b, c pelos seus respctivos textos
df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day' )

# %%
df2.head().T
# Out:
#                                                 0                    1  \
# store                                           1                    2
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        5263                 6064
# customers                                     555                  625
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      c                    a
# assortment                                  basic                basic
# competition_distance                      1270.00               570.00
# ...

# %% [markdown]
# # 3.0 VARIABLE FILTERING

# %%
df3 = df2.copy()

# %%
df3.head()
# Out:
#    store  day_of_week       date  sales  customers  open  promo state_holiday  \
# 0      1            5 2015-07-31   5263        555     1      1   regular_day
# 1      2            5 2015-07-31   6064        625     1      1   regular_day
# 2      3            5 2015-07-31   8314        821     1      1   regular_day
# 3      4            5 2015-07-31  13995       1498     1      1   regular_day
# 4      5            5 2015-07-31   4822        559     1      1   regular_day
#
#    school_holiday store_type  ... is_promo  year  month  day  week_of_year  \
# 0               1          c  ...        0  2015      7   31            31
# 1               1          a  ...        1  2015      7   31            31
# 2               1          a  ...        1  2015      7   31            31
# 3               1          c  ...        0  2015      7   31            31
# 4               1          a  ...        0  2015      7   31            31
#
# ...

# %% [markdown]
# ## 3.1 Line filtering

# %%
# Quero open diferente de zero, pois se a loja está fechada eu não tenho vendas('open'!= 0);
# Quero vendas maior que zero('sales'> 0);

df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2 Selection of columns

# %%
cols_drop= ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop(cols_drop, axis=1)

# %%
df3.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'state_holiday',
#        'school_holiday', 'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_of_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')

# %% [markdown]
# # 4.0 EXPLORATORY DATA ANALYSIS
#
# * **Objetivos**:
#     - Ganhar experoência de Negócios
#     - Validar hipótees de Negócios (Insights)
#     - Perceber as variáveis que são importantes para o Modelo
# ***
# 1. Análise Univariada (variavél):
#     - Como é essa variavél?
#         - Min, Max, Distribuição, Range
# ***
# 2. Análise Bivariada:
#     - Como uma única variavél impacta na resposta?
#         - Correlação, Validação das Hipóteses
# ***
# 3. Análise Multivariada:
#     - Como mais de uma variavél impacta na variavél resposta, e como elas se  relacionam?

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Análise Variavél Resposta

# %%
# Proximo a uma normal, ou seja com ajuste ruim,deslocada para equerda. 
sns.distplot(df4['sales']);
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Caso eu não queira a linhas, apenas o hist

sns.distplot(df4['sales'], kde=False);
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Uma das formas de realizar o ajuste (modificação), para chegar mais proximo da curva normal é multiplicar pelo log
sns.distplot(np.log1p(df4['sales']));

# %%
# Outra forma de fazer
sns.histplot(df4['sales']);

# %%
# Outra forma de fazer
sns.displot(df4['sales']);

# %% [markdown]
# ### 4.1.2 Análise Variavél Numérica

# %%
num_attributes.hist();

# %%
num_attributes.hist(bins=25);

# %%
num_attributes.hist(bins=25);
plt.tight_layout()

# %% [markdown]
# ### 4.1.3 Análise Variavél Categórica

# %%
# Temos 5 variaveis: 
# - Variavéis principais: state_holiday, store_type, assortment
# - Variáveis auxiliares: promo_interval, month_map (essas variavés nos criamos para derivar outras)
cat_attributes.head()
# Out:
#   state_holiday store_type assortment   promo_interval month_map
# 0             0          c          a                0       Jul
# 1             0          a          a  Jan,Apr,Jul,Oct       Jul
# 2             0          a          a  Jan,Apr,Jul,Oct       Jul
# 3             0          c          c                0       Jul
# 4             0          a          a                0       Jul

# %% [markdown]
# ## state_holiday

# %%
# Vamos pegar as variaveis principais e remover as duplicadas, para sabermos quais os tipos de variaveis originais
df4['state_holiday'].drop_duplicates()
# Out:
# 0            regular_day
# 63559     public_holiday
# 129424    easter_holiday
# 241126         christmas
# Name: state_holiday, dtype: object

# %%
# Agora que contar quantas linhas de vendas eu tenho para cada feriado: isso serve para termos uma ideia de volume e saber qual feriado impacta mais nas vendas
# Temos muitas mais vendas em dias normais do que feriados, isso faz sentido, pois temos mais dias normais que feriados em um anos
sns.countplot(df4['state_holiday'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='state_holiday', ylabel='count'>

# %%
# Então vamos filtar o dateset, retirando os dias normais(relugar day)
# Assim podemos obersevar que temos uma volume maior de vendas em feriados públicos --> pascoa --> natal
a= df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='state_holiday', ylabel='count'>

# %%
# Aqui estamos colocando lado a lado: um garáfico com os 3 feriados e o gráfico com a distribuição do public_holiday(feriado público) 
plt.subplot(1,2,1)
a= df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday'])

plt.subplot(1,2,2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday' ,shade=True)
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
# Aqui estamos colocando lado a lado: um garáfico com os 3 feriados e o gráfico com a densidade de distribuição dos feriados individuais
plt.subplot(1,2,1)
a= df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday'])

plt.subplot(1,2,2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday' ,shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday' ,shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'christmas']['sales'], label='christmas' ,shade=True)
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ## store_type

# %%
# Vamos pegar as variaveis principais e remover as duplicadas, para sabermos quais os tipos de variaveis originais
df4['store_type'].drop_duplicates()
# Out:
# 0     c
# 1     a
# 12    d
# 84    b
# Name: store_type, dtype: object

# %%
sns.countplot(df4['store_type'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='store_type', ylabel='count'>

# %%
plt.subplot(1,2,1)
sns.countplot(df4['store_type'])

plt.subplot(1,2,2)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label='a' ,shade=True)
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label='b' ,shade=True)
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label='c' ,shade=True)
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label='d' ,shade=True)
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ## assortment

# %%
# Vamos pegar as variaveis principais e remover as duplicadas, para sabermos quais os tipos de variaveis originais
df4['assortment'].drop_duplicates()
# Out:
# 0         basic
# 3      extended
# 258       extra
# Name: assortment, dtype: object

# %%
sns.countplot(df4['assortment'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='assortment', ylabel='count'>

# %%
plt.subplot(1,2,1)
sns.countplot(df4['assortment'])

plt.subplot(1,2,2)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label='basic' ,shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label='extended' ,shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label='extra' ,shade=True)
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
# Todos os gráfico em um painel

# state_holyday
plt.subplot(3,2,1)
a= df4[df4['state_holiday'] != 'regular_day']
sns.countplot(a['state_holiday'])

plt.subplot(3,2,2)
sns.kdeplot(df4[df4['state_holiday'] == 'public_holiday']['sales'], label='public_holiday' ,shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'easter_holiday']['sales'], label='easter_holiday' ,shade=True)
sns.kdeplot(df4[df4['state_holiday'] == 'christmas']['sales'], label='christmas' ,shade=True)

# store_type
plt.subplot(3,2,3)
sns.countplot(df4['store_type'])

plt.subplot(3,2,4)
sns.kdeplot(df4[df4['store_type'] == 'a']['sales'], label='a' ,shade=True)
sns.kdeplot(df4[df4['store_type'] == 'b']['sales'], label='b' ,shade=True)
sns.kdeplot(df4[df4['store_type'] == 'c']['sales'], label='c' ,shade=True)
sns.kdeplot(df4[df4['store_type'] == 'd']['sales'], label='d' ,shade=True)

# assortment
plt.subplot(3,2,5)
sns.countplot(df4['assortment'])

plt.subplot(3,2,6)
sns.kdeplot(df4[df4['assortment'] == 'basic']['sales'], label='basic' ,shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extended']['sales'], label='extended' ,shade=True)
sns.kdeplot(df4[df4['assortment'] == 'extra']['sales'], label='extra' ,shade=True)
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## 4.2 Análise Bivariada:
#
#     - 1 única variavél sobre a variavél resposta(vendas)

# %% [markdown]
# ##  Hipotéses:
#     1. Lojas com maior sortimentos deveriam vender mais.
#     2. Lojas com competidores mais próximos deveriam vender menos.
#     3. Lojas com competidores à mais tempo deveriam vendem mais.
#     4. Lojas com promoções ativas por mais tempo deveriam vender mais.
#     5. Lojas com mais dias de promoção deveriam vender mais.
#     6. Lojas com mais promoções consecutivas deveriam vender mais.
#     7. Lojas abertas durante o feriado de Natal deveriam vender mais.
#     8. Lojas deveriam vender mais ao longo dos anos.
#     9. Lojas deveriam vender mais no segundo semestre do ano.
#     10. Lojas deveriam vender mais depois do dia 10 de cada mês.
#     11. Lojas deveriam vender menos aos finais de semana.
#     12. Lojas deveriam vender menos durante os feriados escolares

# %% [markdown]
# ### **H1:** Lojas com maior sortimentos deveriam vender mais:
#     Variavél: assortment
#         Falso: Lojas com maior sortimento vendem menos
#         Correlação: (impacto desta variavél sobre a variavél resposta(vendas)): Revelante
#         - Insigth

# %%
# Cada barra descreve a quantidade de vendas por tipo de assortment
# Falso: Lojas com assortment maior(extra) vendem menos

aux1 = df4[['assortment', 'sales']].groupby('assortment').sum().reset_index()
sns.barplot(x='assortment', y='sales', data=aux1);

# Vamos olhar esse comportamento ao longo do tempo
# Confirmamos que a hipotése é falsa, pois mesmo ao longo do tempo o assortmente extra tem vendas baixas
aux2 = df4[['year_week', 'assortment', 'sales']].groupby(['year_week', 'assortment']).sum().reset_index()
aux2.pivot(index='year_week', columns='assortment', values='sales').plot()

# Vamos investigar se o assortment extra é mesmo linear como aponta o gráfico
aux3 = aux2[aux2['assortment'] == 'extra']
aux3.pivot(index='year_week', columns='assortment', values='sales').plot()
# Out:
# <AxesSubplot:xlabel='year_week'>

# %% [markdown]
# ### **H2:** Lojas com competidores mais próximos deveriam vender menos.
#     Variavél: competition_distance
#         Falso: Lojas com competidores mais próximos vendem mais;
#         Correlação: -0.23 (impacto desta variavél sobre a variavél resposta(vendas)): Não Relevante
#         - Insigth

# %%
# Aqui não consguimos ter uma boa visualizações
aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()
sns.barplot(x='competition_distance', y='sales', data=aux1);

# %%
# Estratégia é criar grupos(bins) para melhorar a visualização
aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

bins = list(np.arange(0, 20000, 1000))
aux1['competition_distance_binned'] = pd.cut(aux1['competition_distance'], bins=bins)
aux2 = aux1[['competition_distance_binned', 'sales']].groupby('competition_distance_binned').sum().reset_index()

sns.barplot(x='competition_distance_binned', y='sales', data=aux2);
plt.xticks(rotation=90);

# %%
# Gráfico de pontos: a concentração de vendas realmente está realmente nas lojas com competidores mais próximos

aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()
sns.scatterplot(x= 'competition_distance', y= 'sales', data=aux1);

# %%
# Juntando os gráficos
aux1 = df4[['competition_distance', 'sales']].groupby('competition_distance').sum().reset_index()

# Estratégia é criar grupos(bins) para melhorar a visualização do gráfico
plt.subplot(1,3,1)
bins = list(np.arange(0, 20000, 1000))
aux1['competition_distance_binned'] = pd.cut(aux1['competition_distance'], bins=bins)
aux2 = aux1[['competition_distance_binned', 'sales']].groupby('competition_distance_binned').sum().reset_index()
sns.barplot(x='competition_distance_binned', y='sales', data=aux2);
plt.xticks(rotation=90)

# Gráfico que mostra a concentração de vendas realmente está realmente nas lojas com competidores mais próximos
plt.subplot(1,3,2)
sns.scatterplot(x= 'competition_distance', y= 'sales', data=aux1);

# Força do impacto dessa variavél na variavél resposta(vendas)
plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H3:** Lojas com competidores à mais tempo deveriam vendem mais.
#     Variavél: competition_time_month
#         Falso: Lojas com competidores a mais tempo vendem menos(quanto mais recente mais se vende)
#         Correlação: -0.1 (impacto desta variavél sobre a variavél resposta(vendas)):Não Revelante
#         - Insigth

# %%
# Desta forma não conseguimos visualizar nada no gráfico, pois temos muitos meses
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
sns.barplot(x='competition_time_month', y='sales', data=aux1);

# %%
# Vamos criar um filtro: quanto mais o valor se aproxima de zero maior é o valos da venda

aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
aux2 = aux1[(aux1['competition_time_month'] < 120) & (aux1['competition_time_month'] != 0)]
sns.barplot(x='competition_time_month', y='sales', data=aux2);
plt.xticks(rotation=90);

# %%
# Força da correlação
sns.regplot(x='competition_time_month', y='sales', data=aux2);

# %%
# Juntando os gráficos
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()

plt.subplot(1,3,1)
aux1 = df4[['competition_time_month', 'sales']].groupby('competition_time_month').sum().reset_index()
aux2 = aux1[(aux1['competition_time_month'] < 120) & (aux1['competition_time_month'] != 0)]
sns.barplot(x='competition_time_month', y='sales', data=aux2);
plt.xticks(rotation=90);

# Gráfico que mostra a concentração de vendas
plt.subplot(1,3,2)
sns.regplot(x='competition_time_month', y='sales', data=aux2);

# Força do impacto dessa variavél na variavél resposta(vendas)
plt.subplot(1,3,3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H4:** Lojas com promoções ativas por mais tempo deveriam vender mais.
#     Variavél: promo_time_week
#         Falso: Lojas com promoções ativas por mais tempo (extendida) vendem menos depois de um certo período de promoção.
#         Ou seja, é rentavél por um tempo determinado, depois temos uma queda.
#         Correlação: -0.029 (impacto desta variavél sobre a variavél resposta(vendas)): Não muito relevante
#          - Insight

# %%
# promo_time_week negativa: venda realizada em período regular de promoção
# promo_time_week positivo: venda realizada em período extendido de promoção

aux1 = df4[['promo_time_week','sales']].groupby('promo_time_week').sum().reset_index()
sns.barplot(x='promo_time_week', y='sales', data=aux1);

# %%
# Como temos um grande volume de dados, não é o possivél entender o gráfico. então vamos aplicar um filtro:
# promo extendido > 0
# promo regular < 0

aux1 = df4[['promo_time_week','sales']].groupby('promo_time_week').sum().reset_index()

# colocar um gráfico na última linha do plot sozinho
grid = GridSpec(2,3) 

plt.subplot(grid[0,0])
aux2 = aux1[aux1['promo_time_week'] > 0] # promo extendido
sns.barplot(x='promo_time_week', y='sales', data=aux2);
plt.xticks(rotation=90);


plt.subplot(grid[0,1])
sns.regplot(x='promo_time_week', y='sales', data=aux2); # promo extendido: tendência


plt.subplot(grid[1,0])
aux3 = aux1[aux1['promo_time_week'] < 0] # promo regular
sns.barplot(x='promo_time_week', y='sales', data=aux3);
plt.xticks(rotation=90);

plt.subplot(grid[1,1])
sns.regplot(x='promo_time_week', y='sales', data=aux3); # promo regular: tendência

# Força do impacto dessa variavél na variavél resposta(vendas)
plt.subplot(grid[:,2])
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### <s>**H5:** Lojas com mais dias de promoção deveriam vender mais.<s>
#     Variavél:
#         Falso:
#         Correlação:

# %% [markdown]
# ### **H6:** Lojas com mais promoções consecutivas deveriam vender mais.
#     Variavél:promo/ promo2
#         Falso: Lojas com mais promoções consecutivas vendem menos
#         Correlação: (impacto desta variavél sobre a variavél resposta(vendas)): Pouco Relevante
#         - Insigth

# %%
# Aqui podemos percerber que mesmo as lojas que não partiparam de nenhuma promoção tiveram boas vendas
df4[['promo', 'promo2', 'sales']].groupby(['promo', 'promo2']).sum().sort_values('sales').reset_index()
# Out:
#    promo  promo2       sales
# 0      0       1  1289362241
# 1      1       1  1472275754
# 2      0       0  1482612096
# 3      1       0  1628930532

# %%
# Aqui temos lojas que as lojas que tiveram os dois períodos de promoção:
# Participaram da promo(regular) == 1
# Participaram da promo(extendida) == 1

aux1 = df4[(df4['promo'] == 1) & (df4['promo2'] == 1)][['year_week', 'sales']].groupby('year_week').sum().reset_index()
aux1.plot()
# Out:
# <AxesSubplot:>

# %%
# Aqui temos lojas que as lojas que tiveram os dois períodos de promoção:
# Participaram da promo(regular) == 1
# Participaram da promo(extendida) == 1

aux1 = df4[(df4['promo'] == 1) & (df4['promo2'] == 1)][['year_week', 'sales']].groupby('year_week').sum().reset_index()
ax = aux1.plot()

# Participaram da promo(regular) == 1
# Participaram da promo(extendida) == 0

aux2 = df4[(df4['promo'] == 1) & (df4['promo2'] == 0)][['year_week', 'sales']].groupby('year_week').sum().reset_index()
aux2.plot(ax=ax)

ax.legend(labels=['Regular & Extendida', 'Extendida']);

# %% [markdown]
# ### **H7:** Lojas abertas durante o feriado de Natal deveriam vender mais.
#     Variavél: state_holiday
#         Falso: Lojas abertar durante o feriado de Natal vendem menos. Este comportamento se repete ao longo dos anos.
#         Correlação: (impacto desta variavél sobre a variavél resposta(vendas)): Relevante

# %%
aux = df4[df4['state_holiday'] != 'regular_day']
aux1 = aux[['state_holiday', 'sales']].groupby('state_holiday').sum().reset_index()
sns.barplot(x='state_holiday', y='sales', data=aux1);

# %%
# Vamos ver ao longo do tempo
aux2 = aux[['year', 'state_holiday', 'sales']].groupby(['year', 'state_holiday']).sum().reset_index()
sns.barplot(x='state_holiday', y='sales', hue='state_holiday', data=aux2);

# %%
# Juntando os gráfico

plt.subplot(1,2,1)
aux = df4[df4['state_holiday'] != 'regular_day']
aux1 = aux[['state_holiday', 'sales']].groupby('state_holiday').sum().reset_index()
sns.barplot(x='state_holiday', y='sales', data=aux1);

plt.subplot(1,2,2)
# Vamos ver ao longo do tempo
aux2 = aux[['year', 'state_holiday', 'sales']].groupby(['year', 'state_holiday']).sum().reset_index()
sns.barplot(x='year', y='sales', hue='state_holiday', data=aux2);

# %% [markdown]
# ### **H8:** Lojas deveriam vender mais ao longo dos anos.
#     Variavél: year
#         Falso: Lojas vendem menos ao longo dos anos
#         Correlação: -0,92 (impacto desta variavél sobre a variavél resposta(vendas)): Muito Revelante
#         Atenção: o ano de 2015 não está fechado, devemos pegar períodos fechados

# %%
aux1 = df4[['year', 'sales']].groupby('year').sum().reset_index()

plt.subplot(1,3,1)
sns.barplot(x='year', y='sales', data=aux1);

plt.subplot(1,3,2) # Tendência
sns.regplot(x='year', y='sales', data=aux1);

plt.subplot(1,3,3) # Correlação
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H9:** Lojas deveriam vender mais no segundo semestre do ano.
#     Variavél: month
#         Falso: Lojas vendem menos no segundo semestre do ano
#         Correlação:-0.75 (impacto desta variavél sobre a variavél resposta(vendas)): Muito Revelante

# %%
aux1 = df4[['month', 'sales']].groupby('month').sum().reset_index()

plt.subplot(1,3,1)
sns.barplot(x='month', y='sales', data=aux1);

plt.subplot(1,3,2) # Tendência
sns.regplot(x='month', y='sales', data=aux1);

plt.subplot(1,3,3) # Correlação
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H10:** Lojas deveriam vender mais depois do dia 10 de cada mês.
#     Variavél:day
#         Verdadeira:Lojas vendem mais depois do dia 10 de cada mês
#         Correlação: -0.35 (impacto desta variavél sobre a variavél resposta(vendas)): Revelante

# %%
aux1 = df4[['day', 'sales']].groupby('day').sum().reset_index()

plt.subplot(2,2,1)
sns.barplot(x='day', y='sales', data=aux1);

plt.subplot(2,2,2) # Tendência
sns.regplot(x='day', y='sales', data=aux1);

plt.subplot(2,2,3) # Correlação
sns.heatmap(aux1.corr(method='pearson'), annot=True);

plt.subplot(2,2,4) # 
# Criando uma nova coluna que me diz se a venda foi antes ou depois do dia 10
aux1['before_after'] = aux1['day'].apply(lambda x: 'before_10_days' if x <= 10 else 'after_10_days')

aux2 = aux1[['before_after', 'sales']].groupby('before_after').sum().reset_index()
sns.barplot(x='before_after', y='sales', data=aux2);

# %% [markdown]
# ### **H11:** Lojas deveriam vender menos aos finais de semana.
#     Variavél:day_of_week
#         Verdadeiro: Lojas vendem menos nos finais de semana
#         Correlação: -0.76 (impacto desta variavél sobre a variavél resposta(vendas)): Muito Revelante

# %%
aux1 = df4[['day_of_week', 'sales']].groupby('day_of_week').sum().reset_index()

plt.subplot(1,3,1)
sns.barplot(x='day_of_week', y='sales', data=aux1);

plt.subplot(1,3,2) # Tendência
sns.regplot(x='day_of_week', y='sales', data=aux1);

plt.subplot(1,3,3) # Correlação
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### **H12:** Lojas deveriam vender menos durante os feriados escolares
#     Variavél:
#         Verdadeira: Lojas vendem menos durante os feriados escolares, except os meses de julho e agosto
#         Correlação: (impacto desta variavél sobre a variavél resposta(vendas)): Revelante

# %%
# Juntando os gráfico

plt.subplot(2,1,1)
aux1 = df4[['school_holiday', 'sales']].groupby('school_holiday').sum().reset_index()
sns.barplot(x='school_holiday', y='sales', data=aux1);


# Vamos ver ao longo do tempo
plt.subplot(2,1,2)
aux2 = df4[['month', 'school_holiday', 'sales']].groupby(['month', 'school_holiday']).sum().reset_index()
sns.barplot(x='month', y='sales', hue='school_holiday', data=aux2);

# %% [markdown]
# ## 4.2.1  Resumo das Hipoteses

# %%
tab = [['Hipoteses', 'Conclusao', 'Relevancia'],
       ['H1', 'Falsa', 'Baixa'],
       ['H2', 'Falsa', 'Media'],
       ['H3', 'Falsa', 'Media'],
       ['H4', 'Falsa', 'Baixa'],
       ['H5', '-', '-'],
       ['H6', 'Falsa', 'Baixa'],
       ['H7', 'Falsa', 'Media'],
       ['H8', 'Falsa', 'Alta'],
       ['H9', 'Falsa', 'Alta'],
       ['H10', 'Verdadeira', 'Alta'],
       ['H11', 'Verdadeira', 'Alta'],
       ['H12', 'Verdadeira', 'Baixa'],
       ]
print(tabulate(tab, headers='firstrow'))
# Out:
# Hipoteses    Conclusao    Relevancia
# -----------  -----------  ------------
# H1           Falsa        Baixa
# H2           Falsa        Media
# H3           Falsa        Media
# H4           Falsa        Baixa
# H5           -            -
# H6           Falsa        Baixa
# H7           Falsa        Media
# H8           Falsa        Alta
# H9           Falsa        Alta
# H10          Verdadeira   Alta
# H11          Verdadeira   Alta
# H12          Verdadeira   Baixa

# %% [markdown]
# ## 4.3 Análise Multivariada

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
correlation = num_attributes.corr(method='pearson')
sns.heatmap(correlation, annot=True);

# %% [markdown]
# ### 4.3.2 Categorical  Attributes

# %%
# only categorical data
a = df4.select_dtypes(include='object')
a.head()
# Out:
#   state_holiday store_type assortment year_week
# 0   regular_day          c      basic   2015-30
# 1   regular_day          a      basic   2015-30
# 2   regular_day          a      basic   2015-30
# 3   regular_day          c   extended   2015-30
# 4   regular_day          a      basic   2015-30

# %%
# Calculate cramer v
a1 = cramer_v(a['state_holiday'], a['state_holiday'])
a2 = cramer_v(a['state_holiday'], a['store_type'])
a3 = cramer_v(a['state_holiday'], a['assortment'])

a4 = cramer_v(a['store_type'], a['state_holiday'])
a5 = cramer_v(a['store_type'], a['store_type'])
a6 = cramer_v(a['store_type'], a['assortment'])

a7 = cramer_v(a['assortment'], a['state_holiday'])
a8 = cramer_v(a['assortment'], a['store_type'])
a9 = cramer_v(a['assortment'], a['assortment'])

# Final dataset
d = pd.DataFrame({'state_holiday': [a1,a2,a3],
                  'store_type'   : [a4,a5,a6],
                  'assortment'   : [a7,a8,a9] })

d = d.set_index(d.columns)
d
# Out:
#                state_holiday  store_type  assortment
# state_holiday           1.00        0.07        0.07
# store_type              0.07        1.00        0.54
# assortment              0.07        0.54        1.00

# %%
sns.heatmap(d, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 5.0 DATA MODELING:
#
# * Normalização (variáveis com distribuição normal)
#     - Rescala o centro para 0 com desvio-padrão igual a 1;
#
#
# * Rescaling (variáveis sem distribuição normal)
#     - Rescala para o intervalo entre 0 e 1
#     - Distribuição não Gaussianas (não normal)
#
# * Transformação
#     - Conversão de Features Categóricas para Numéricas (ENCODING)
#     - Transformação de Natureza (variaveis de tempo)
#     - Transformação de Grandeza

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Normalização:
#
# * Média
# * Desvio-padrão
#
# Nosso conjunto de dados numéricos não possuem variáveis com distribuição normal: 4.1.2 Análise Variavél Numérica

# %% [markdown]
# ## 5.2 Rescaling:
#
# * Min-Max Scaler (para variáveis com baixos outliers)
#     - Média
#     - Min
#     - Max
#
# * Robust Scaler (para variáveis com baixos outliers)
#     - Média
#     - 3º quartil
#     - 1º quartil

# %%
a = df5.select_dtypes(include=['int64', 'float64'])
a.head()
# Out:
#    store  day_of_week  sales  promo  school_holiday  competition_distance  \
# 0      1            5   5263      1               1               1270.00
# 1      2            5   6064      1               1                570.00
# 2      3            5   8314      1               1              14130.00
# 3      4            5  13995      1               1                620.00
# 4      5            5   4822      1               1              29910.00
#
#    competition_open_since_month  competition_open_since_year  promo2  \
# 0                             9                         2008       0
# 1                            11                         2007       1
# 2                            12                         2006       1
# 3                             9                         2009       0
# 4                             4                         2015       0
#
#    promo2_since_week  promo2_since_year  is_promo  year  month  day
# ...

# %% [markdown]
# ## competition_distance

# %%
# Outliers bem definidos: Robust Scaler
sns.boxplot(df5['competition_distance'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='competition_distance'>

# %%
rs = RobustScaler()

df5['competition_distance'] = rs.fit_transform(df5[['competition_distance']].values)

# %%
sns.distplot(df5['competition_distance'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='competition_distance', ylabel='Density'>

# %% [markdown]
# ## competition_time_month

# %%
# Outliers bem definidos: Robust Scaler
sns.boxplot(df5['competition_time_month'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='competition_time_month'>

# %%
rs = RobustScaler()

df5['competition_time_month'] = rs.fit_transform(df5[['competition_time_month']].values)

# %%
sns.distplot(df5['competition_time_month'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='competition_time_month', ylabel='Density'>

# %% [markdown]
# ## promo_time_week

# %%
# Outliers não tão definidos(altos) definidos: Min-Max Scaler
sns.boxplot(df5['promo_time_week'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='promo_time_week'>

# %%
mms = MinMaxScaler()

df5['promo_time_week'] = mms.fit_transform(df5[['promo_time_week']].values)

# %% [markdown]
# ## year

# %%
# Outliers não tão definidos(altos) definidos: Min-Max Scaler
sns.boxplot(df5['year'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year'>

# %%
mms = MinMaxScaler()

df5['year'] = mms.fit_transform(df5[['year']].values)

# %% [markdown]
# ## 5.3 Transformação

# %% [markdown]
# ## 5.3.1 Transformação ENCODING:
#     - Variavés Categóricas
#
# * One Hot Encoding
# * Label Encoding
# * Ordinal Encoding
# * Target Encoding
# * Frequency Encoding
# * Embedding Encoding

# %%
df5.head()
# Out:
#    store  day_of_week       date  sales  promo state_holiday  school_holiday  \
# 0      1            5 2015-07-31   5263      1   regular_day               1
# 1      2            5 2015-07-31   6064      1   regular_day               1
# 2      3            5 2015-07-31   8314      1   regular_day               1
# 3      4            5 2015-07-31  13995      1   regular_day               1
# 4      5            5 2015-07-31   4822      1   regular_day               1
#
#   store_type assortment  competition_distance  ...  is_promo  year  month  \
# 0          c      basic                 -0.17  ...         0  1.00      7
# 1          a      basic                 -0.28  ...         1  1.00      7
# 2          a      basic                  1.90  ...         1  1.00      7
# 3          c   extended                 -0.28  ...         0  1.00      7
# 4          a      basic                  4.45  ...         0  1.00      7
#
# ...

# %% [markdown]
# ## state _holiday

# %%
# One Hot Encoding
df5 = pd.get_dummies(df5, prefix=['state_holiday'], columns=['state_holiday'])

# %% [markdown]
# ## store_type

# %%
# Label Encoding
le = LabelEncoder()

df5['store_type'] = le.fit_transform(df5['store_type'])

# %% [markdown]
# ## assortment

# %%
df5['assortment'].drop_duplicates()
# Out:
# 0         basic
# 3      extended
# 258       extra
# Name: assortment, dtype: object

# %%
# Ordinal Encoding

assortment_dict = {'basic'   : 1,
                   'extra'   : 2,
                   'extended': 3
                  }

df5['assortment'] = df5['assortment'].map(assortment_dict)

# %% [markdown]
# ## 5.3.2 Response Variable Transformation
# ###          Transformação de  Grandeza:
#                 * Trazer a variavel resposta com distribuição mais próxima da normal
#
# 1. Logarithm Transformation
# 2. Box-Cox Transformation
# 3. Cube-Root Transformation
# 4. Square-Root Transformation
# 5. Sine and Cosine Transformation

# %%
df5['sales'] = np.log1p(df5['sales'])

# %%
sns.distplot(df5['sales'])
# Out:
# C:\Users\Utilizador\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# ## 5.3.3 Nature Transformation
# ###         Transformação de Natureza Ciclíca
#                 * Trazer a natureza real para seu conjunto de dados

# %% [markdown]
# ## month

# %%
df5['month_sin'] = df5['month'].apply(lambda x: np.sin(x * (2. * np.pi/12)))
df5['month_cos'] = df5['month'].apply(lambda x: np.cos(x * (2. * np.pi/12)))

# %% [markdown]
# ## week_of_year

# %%
df5['week_of_year_sin'] = df5['week_of_year'].apply(lambda x: np.sin(x * (2. * np.pi/52)))
df5['week_of_year_cos'] = df5['week_of_year'].apply(lambda x: np.cos(x * (2. * np.pi/52)))

# %% [markdown]
# ## day_of_week

# %%
df5['day_of_week_sin'] = df5['day_of_week'].apply(lambda x: np.sin(x * (2. * np.pi/7)))
df5['day_of_week_cos'] = df5['day_of_week'].apply(lambda x: np.cos(x * (2. * np.pi/7)))

# %% [markdown]
# ## day

# %%
df5['day_sin'] = df5['day'].apply(lambda x: np.sin(x * (2. * np.pi/30)))
df5['day_cos'] = df5['day'].apply(lambda x: np.cos(x * (2. * np.pi/30)))

# %%
df5.head()
# Out:
#    store  day_of_week       date  sales  promo  school_holiday  store_type  \
# 0      1            5 2015-07-31   8.57      1               1           2
# 1      2            5 2015-07-31   8.71      1               1           0
# 2      3            5 2015-07-31   9.03      1               1           0
# 3      4            5 2015-07-31   9.55      1               1           2
# 4      5            5 2015-07-31   8.48      1               1           0
#
#    assortment  competition_distance  competition_open_since_month  ...  \
# 0           1                 -0.17                             9  ...
# 1           1                 -0.28                            11  ...
# 2           1                  1.90                            12  ...
# 3           3                 -0.28                             9  ...
# 4           1                  4.45                             4  ...
#
#    state_holiday_public_holiday  state_holiday_regular_day  month_sin  \
# ...

# %% [markdown]
# # 6.0 FEATURE SELECTION:
#
# * Remover variáveis colineares: são variáveis que explicam a mesma coisa (o mesmo fenômeno)
#
#     * Métodos de seleção de variáveis:  classifica as variáveis como relevante ou não relevante.
#     * Ou seja, encontrar dentre todas as minhas variáveis quais delas explicam a maior parte/ ou melhor o meu fenômeno.
#          * Dê sempre preferência para o mais simples
#
# 1. Filter Methods (Seleção Univariada): Usa a Correlação como um critério para classicficar a variável como
#    importante ou não importante para o modelo.
#
#             - Coeficiente de correlação:
#                                        |-1 (correlação forte negativamente): sentidos contrários|
#                                        | 0 (correlação fraca: positiva ou negativa)             |
#                                        | 1 (correlação forte positivamente): mesmo sentido      |
#
#             * Vantagens: Simples, Rápido e de fácil entendimento
#             * Desvantagens: Não considera a influência entre as variáveis (1 variavél e a variavél resposta)
#
#
# 2. Embedded Methods (Seleção por importância): Usa a Importância como um critério para classicficar a variável como
#    importante ou não importante para o modelo.
#
#             1. Random Forest: Gini impurity (homogeneidade)
#             2. Lasso Regression: Método embutido
#             3. Ridge Regression: Método embutido
#
#
# 3. Wrapper Methods (Seleção por SubSet): BORUTA
#    - Método diferente dos outros (conceito diferente)
#     - É uma sequência de passos:
#         1. Selecione uma única variável (aleatoriamente) + a variavél resposta;
#         2. Treine um modelo de Machine Learing;
#         3. Calcule a performace do Modelo ( Acurácia ou erro);
#         4. A performace aumentou?
#                                   - Se sim, matém a variavél.
#                                   - Se não, remova essa variavél.
#
#         5. Adicione uma nova varável: Agora vc tem 2 variavéis + a variavél resposta;
#         6. Volte no passo 2
#
#         Faz isso, até passar por todas as variavéis. No final você terá um novo subset com as variavéis mais relecantes.

# %%
df6 = df5.copy()

# %% [markdown]
# ## 6.1 Split dataframe into training and test dataset

# %%
df6.head()
# Out:
#    store  day_of_week       date  sales  promo  school_holiday  store_type  \
# 0      1            5 2015-07-31   8.57      1               1           2
# 1      2            5 2015-07-31   8.71      1               1           0
# 2      3            5 2015-07-31   9.03      1               1           0
# 3      4            5 2015-07-31   9.55      1               1           2
# 4      5            5 2015-07-31   8.48      1               1           0
#
#    assortment  competition_distance  competition_open_since_month  ...  \
# 0           1                 -0.17                             9  ...
# 1           1                 -0.28                            11  ...
# 2           1                  1.90                            12  ...
# 3           3                 -0.28                             9  ...
# 4           1                  4.45                             4  ...
#
#    state_holiday_public_holiday  state_holiday_regular_day  month_sin  \
# ...

# %%
df6.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'school_holiday',
#        'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_of_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week',
#        'state_holiday_christmas', 'state_holiday_easter_holiday',
#        'state_holiday_public_holiday', 'state_holiday_regular_day',
#        'month_sin', 'month_cos', 'week_of_year_sin', 'week_of_year_cos',
#        'day_of_week_sin', 'day_of_week_cos', 'day_sin', 'day_cos'],
#       dtype='object')

# %%
cols_drop = ['week_of_year', 'day', 'month', 'day_of_week', 'promo_since', 'competition_since', 'year_week']
df6 = df6.drop(cols_drop, axis=1)

# %%
# Agrupando o dataset por loja e data;
# Calculando a data mínima;
# Esta será a minha primeira data do conjunto de treino
df6[['store', 'date']].groupby('store').min().reset_index()
# Out:
#       store       date
# 0         1 2013-01-02
# 1         2 2013-01-02
# 2         3 2013-01-02
# 3         4 2013-01-02
# 4         5 2013-01-02
# ...     ...        ...
# 1110   1111 2013-01-02
# 1111   1112 2013-01-02
# 1112   1113 2013-01-02
# 1113   1114 2013-01-02
# 1114   1115 2013-01-02
#
# [1115 rows x 2 columns]

# %%
# Agrupando o dataset por loja e data;
# Calculando a data máxima para podermos calcular semanas anterior
# Esta será a minha última data do conjunto de treino
df6[['store', 'date']].groupby('store').max().reset_index()
# Out:
#       store       date
# 0         1 2015-07-31
# 1         2 2015-07-31
# 2         3 2015-07-31
# 3         4 2015-07-31
# 4         5 2015-07-31
# ...     ...        ...
# 1110   1111 2015-07-31
# 1111   1112 2015-07-31
# 1112   1113 2015-07-31
# 1113   1114 2015-07-31
# 1114   1115 2015-07-31
#
# [1115 rows x 2 columns]

# %%
# Aqui preciso saber qual a data que começa as s semanas antes do final 
# Selecionando a linha 0 da minha coluna date
df6[['store', 'date']].groupby('store').max().reset_index()['date'][0]
# Out:
# Timestamp('2015-07-31 00:00:00')

# %%
# Aqui estamos subtraindo uma semana da data máxima;
# Para descobrirmos onde terminará nosso período de treino
df6[['store', 'date']].groupby('store').max().reset_index()['date'][0] - datetime.timedelta(days=7)
# Out:
# Timestamp('2015-07-24 00:00:00')

# %%
# Aqui estamos subtraindo uma 6 semanas (6*7) da data máxima;
# Para descobrirmos onde terminará nosso período de treino
df6[['store', 'date']].groupby('store').max().reset_index()['date'][0] - datetime.timedelta(days=6*7)
# Out:
# Timestamp('2015-06-19 00:00:00')

# %% [markdown]
# ### TREINO:
#     Primeira data de venda: 01-01-2013
#     última data de treino: 18-06-2015
#
# ### TESTE:
#     Primeira data de Teste: 19-06-2015
#     última data de venda: 31-07-2015

# %%
# training dataset
X_train = df6[df6['date'] < '2015-06-19']
Y_train = X_train['sales']

# test dataset
X_test = df6[df6['date'] >= '2015-06-19']
Y_test = X_test['sales']

print( 'Training Min Date: {}'.format(X_train['date'].min()))
print( 'Training Max Date: {}'.format(X_train['date'].max()))

print( '\nTest Min Date: {}'.format(X_test['date'].min()))
print( 'Test Max Date: {}'.format(X_test['date'].max()))
# Out:
# Training Min Date: 2013-01-01 00:00:00
# Training Max Date: 2015-06-18 00:00:00
#
# Test Min Date: 2015-06-19 00:00:00
# Test Max Date: 2015-07-31 00:00:00

# %% [markdown]
# ## 6.2 Boruta as Feature Selector

# %%
# training and test dataset for Boruta
#X_train_n = X_train.drop(['date', 'sales'], axis=1).values
#Y_train_n = Y_train.values.ravel()


# define RandomForestRegressor
#rf = RandomForestRegressor(n_jobs=-1)

# define Boruta
#boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(X_train_n, Y_train_n)

# %% [markdown]
# ### 6.2.1 Best Features from Boruta

# %%
#cols_selected = boruta.support_.tolist()

# best features
#X_train_fs = X_train.drop(['date', 'sales'], axis=1)
#cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()

# not selected boruta
#cols_not_selected_boruta = list(np.setdiff1d(X_train_fs.columns, cols_selected_boruta))

# %%
#cols_selected_boruta

# %%
#cols_not_selected_boruta

# %% [markdown]
# ## 6.3 Manual Feature Selection

# %%
cols_selected_boruta =[
    'store',
    'promo',
    'store_type',
    'assortment',
    'competition_distance',
    'competition_open_since_month',
    'competition_open_since_year',
    'promo2',
    'promo2_since_week',
    'promo2_since_year',
    'competition_time_month',
    'promo_time_week',
    'month_sin',
    'month_cos',
    'week_of_year_sin',
    'week_of_year_cos',
    'day_of_week_sin',
    'day_of_week_cos',
    'day_sin',
    'day_cos']

# %%
# columns to add
feat_to_add = ['date', 'sales']

# final features
cols_selected_boruta_full = cols_selected_boruta.copy()
cols_selected_boruta_full.extend(feat_to_add)

# %% [markdown]
# # 7.0 MACHINE LEARNING MODELLING:
#
# * Tipos de modelos:
#     1. Supervisionado:
#         - Classificação: doenças, objetos, fraude, ... etc
#         - Regressão: previsão de vendas, valor e vendas de casas, dimensões casas, ... etc
#         - Séries Temporais (Modelo de Previsão): receita, custo, nº de funcionários, novos usuários, ... etc
#     2. Não Supervisionada:
#         - Clusterização (Agrupamento)
#     3. Semi- Supervisionado: Agente (Ação) ------> Ambiente (Recompensa)
#         - Reinforcement Learning

# %% [markdown]
# ## Cross- Validation:
#
#      Classificação/ Regressão
#
# ## Time Series Cross- Validation:
#
#      Séries Temporais

# %% [markdown]
# * Aplicaremos:
#     1. Average Model (Modelo de Média): objetivo é servir de base comparativa para comparação de performace aos outros modelos;
#     2. Linear Regression (linear)
#     3. Linear Regression Regularized (linear)
#     4. Random Forest Regressor (não lineares)
#     5. XGBoost Regressor (não lineares)

# %%
x_train = X_train[cols_selected_boruta]
x_test = X_test[cols_selected_boruta]

x_training = X_train[cols_selected_boruta_full]

# %% [markdown]
# ## 7.1 Average Modelo

# %%
#copying test variables
#aux1 = x_test.copy()
#aux1['sales'] = Y_test.copy()

#calculation sales prediction by mean by store
#aux2 = aux1[['store', 'sales']].groupby('store').mean().reset_index().rename(columns={'sales': 'predictions'})
#aux1 = pd.merge(aux1, aux2, how = 'left', on='store')
#yhat_baseline = aux1['predictions']

# %%
# performance
baseline_result = ml_error('Average Model', np.expm1(Y_test), np.expm1(yhat_baseline))
baseline_result

# %% [markdown]
# ## 7.2 Linear Regression Model

# %%
#model
#lr = LinearRegression().fit(x_train, Y_train)

#prediction
#yhat_lr = lr.predict(x_test)

#performance
#lr_result = ml_error('Linear Regression', np.expm1(Y_test), np.expm1(yhat_lr))
#lr_result

# %% [markdown]
# ### 7.2.1 Linear Regression - Cross Validation

# %%
#lr = LinearRegression()
#lr_result_cv = cross_validation(x_training, 5, 'Linear Regression', lr, verbose=False)
#lr_result_cv

# %% [markdown]
# ## 7.3 Linear Regression Regularized Model - Lasso

# %%
#model
#lrr = Lasso(alpha=0.01).fit(x_train, Y_train)

#prediction
#yhat_lrr = lrr.predict(x_test)

#performance
#lrr_result = ml_error('Linear Regression - Lasso', np.expm1(Y_test), np.expm1(yhat_lrr))
#lrr_result

# %% [markdown]
# ### 7.3.1 Lasso - Cross Validation

# %%
#lrr = Lasso()
#lrr_result_cv = cross_validation(x_training, 5, 'Lasso', lrr, verbose=False)
#lrr_result_cv

# %% [markdown]
# ## 7.4. Random Forest Regressor

# %%
#model
#rf = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=41).fit(x_train, Y_train)
#pickle.dump(rf, open( path + '/model/rf_model.pkl', 'wb'))
# rf = pickle.load(open( path + '/model/rf_model.pkl', 'rb'))

#prediction
#yhat_rf = rf.predict(x_test)

#performance
#rf_result = ml_error('Random Forest Regressor', np.expm1(Y_test), np.expm1(yhat_rf))
#rf_result

# %% [markdown]
# ### 7.4.1 Random Forest Regressor - Cross Validation

# %%
#rf = RandomForestRegressor()
#rf_result_cv = cross_validation(x_training, 5, 'Random Forest Regressor', rf, verbose=True)
#rf_result_cv

# %% [markdown]
# ## 7.5. XGBoost Regressor

# %%
#model_xgb = xgb.XGBRegressor( objective='reg:squarederror',
#                              n_estimators=100).fit( x_train, Y_train )

#prediction
#yhat_xgb = model_xgb.predict(x_test)

#performance
#xgb_result = ml_error('XGBoost Regressor', np.expm1(Y_test), np.expm1(yhat_xgb))
#xgb_result

# %% [markdown]
# ### 7.5.1 XGBoost Regressor - Cross Validation

# %%
#model_xgb = xgb.XGBRegressor()
#xgb_result_cv = cross_validation(x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True)
#xgb_result_cv

# %% [markdown]
# ## 7.6. Compare Model's Performance

# %% [markdown]
# ### 7.6.1 Single Performance

# %%
#modelling_result = pd.concat([baseline_result, lr_result, lrr_result, rf_result, xgb_result])
#modelling_result.sort_values('RMSE')

# %% [markdown]
# ### 7.6.1. Real Performance - Cross Validation

# %%
#modelling_result_cv = pd.concat([ lr_result_cv, lrr_result_cv, rf_result_cv, xgb_result_cv])
#modelling_result_cv.sort_values('RMSE CV')

# %% [markdown]
# # 8.0 HYPERPARAMETER FINE TUNNING:
#
#     Objetivo: Encontrar o conjunto de parâmetros que maximiza o aprendizado do modelo
#
#         Estratégias:
#             1. Random Search: define valores para cada um dos hiperparâmetros aleatoriamente;
#                 - Vantagem: Rápido/ Baixo custo
#                 - Desvantagem: Define os valores aleatoriamete
#
#             2. Grid Search: define todas as combinações possíveos de valores que os hiperparâmetros podem assumir;
#                 - Vantagem:Define os verdadeiros valores que maximizam o aprendizado do modelo
#                 - Desvantagem: Muito demorado/ Alto custo
#
#             3. Bayesian Search: define valores para os hiperparâmetros seguindo a teoria de Bayes.
#                 - Vantagem: Define os valores para os hiperparâmetros baseado em aprendizados passados
#                 - Desvantagem: Mais complexo de aprendizado. Mais rápido que o Grid e mais lento que o Random

# %% [markdown]
# ## 8.1. Random Search

# %%
#warnings.filterwarnings('ignore')

# %%
#param = {'n_estimators': [1500, 1700, 2500, 3000, 3500],
 #        'eta': [0.01, 0.03],
 #        'max_depth': [3, 5, 9],
 #        'subsample': [0.1, 0.5, 0.7],
 #        'colsample_bytree': [0.3, 0.7, 0.9],
 #        'min_child_weight': [3, 8, 15]
 #       }

#MAX_EVAL = 5

# %%
#final_result = pd.DataFrame()

#for i in range( MAX_EVAL ):
 #   # choose values for parameters randomly
 #   hp = { k: random.sample(  v, 1 )[0] for k, v in param.items() }
 #   print( hp )

    # model
 #   model_xgb = xgb.XGBRegressor( objective='reg:squarederror',
 #                                  n_estimators=hp['n_estimators'],
 #                                  eta=hp['eta'],
 #                                  max_depth=hp['max_depth'],
 #                                  subsample=hp['subsample'],
 #                                  colsample_bytree=hp['colsample_bytree'],
 #                                  min_child_weight=hp['min_child_weight'] )
 #   
    # Performance
 #   result = cross_validation(x_training, 5, 'XGBoost Regressor', model_xgb, verbose=True)
 #   final_result = pd.concat([final_result, result])

#final_result
# Out:
# {'n_estimators': 3500, 'eta': 0.03, 'max_depth': 9, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 8}
# KFold Number: 5
# KFold Number: 4
# KFold Number: 3
# KFold Number: 2
# KFold Number: 1
# {'n_estimators': 2500, 'eta': 0.01, 'max_depth': 5, 'subsample': 0.7, 'colsample_bytree': 0.3, 'min_child_weight': 3}
# KFold Number: 5
# KFold Number: 4
# KFold Number: 3
# KFold Number: 2
# KFold Number: 1
# {'n_estimators': 1500, 'eta': 0.01, 'max_depth': 3, 'subsample': 0.7, 'colsample_bytree': 0.3, 'min_child_weight': 3}
# KFold Number: 5
# KFold Number: 4
# KFold Number: 3
# KFold Number: 2
# KFold Number: 1
# {'n_estimators': 3000, 'eta': 0.01, 'max_depth': 9, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 15}
# KFold Number: 5
# KFold Number: 4
# KFold Number: 3
# KFold Number: 2
# KFold Number: 1
# {'n_estimators': 3500, 'eta': 0.01, 'max_depth': 9, 'subsample': 0.5, 'colsample_bytree': 0.9, 'min_child_weight': 8}
# KFold Number: 5
# KFold Number: 4
# ...

# %% [markdown]
# ## 8.2. Final Model

# %%
#param_tuned = {'n_estimators': 1500, 
 #              'eta': 0.03, 
 #             'max_depth': 5, 
 #              'subsample': 0.5, 
 #              'colsample_bytree': 0.9, 
 #              'min_child_weight': 15}

# model
#model_xgb_tuned = xgb.XGBRegressor( objective='reg:squarederror',
 #                                  n_estimators=param_tuned['n_estimators'],
 #                                  eta=param_tuned['eta'],
 #                                  max_depth=param_tuned['max_depth'],
 #                                  subsample=param_tuned['subsample'],
 #                                  colsample_bytree=param_tuned['colsample_bytree'],
 #                                  min_child_weight=param_tuned['min_child_weight'] ).fit( x_train, Y_train )

                                   
# prediction
#yhat_xgb_tuned = model_xgb_tuned.predict( x_test )

# performance
#xgb_result_tuned = ml_error( 'XGBoost Regressor', np.expm1( Y_test ), np.expm1(yhat_xgb_tuned ) )
#xgb_result_tuned
# Out:
#           Model Name    MAE  MAPE    RMSE
# 0  XGBoost Regressor 918.33  0.14 1332.17

# %%
#param_tuned = {'n_estimators': 3500,
 #              'eta': 0.03,
 #              'max_depth': 9,
 #              'subsample': 0.7,
 #              'colsample_bytree': 0.7,
 #              'min_child_weight': 8}

# model
#model_xgb_tuned = xgb.XGBRegressor(objective='reg:squarederror',
 #                                  n_estimators=param_tuned['n_estimators'],
 #                                  eta=param_tuned['eta'],
 #                                  max_depth=param_tuned['max_depth'],
 #                                  subsample=param_tuned['subsample'],
 #                                  colsample_bytree=param_tuned['colsample_bytree'],
 #                                  min_child_weight=param_tuned['min_child_weight']).fit( x_train, Y_train )

#prediction
#yhat_xgb_tuned = model_xgb_tuned.predict( x_test )

# performance
#xgb_result_tuned = ml_error( 'XGBoost Regressor', np.expm1( Y_test ), np.expm1(yhat_xgb_tuned ) )
#xgb_result_tuned
# Out:
#           Model Name    MAE  MAPE   RMSE
# 0  XGBoost Regressor 612.52  0.09 895.57

# %%
pickle.dump(model_xgb_tuned, open('C:/Users/Utilizador/repos/Data_Science_em_Producao/model_rossmann.pkl', 'wb'))

# %% [markdown]
# # 9.0 TRANSLATION AND INTERPRETATION OF THE ERROR
#
#     1. Performance do Modelo de Regressão
#      - MAE (Mean Absolute Error)
#      - MAPE (Mean Absolute Percentage Error)
#      - RMSE (Root Mean Squared Error)
#      - MPE (Mean Percentage Error)
#
#     2. Performace do Modelo sobre o negócio
#      - Comparação com o Status quo
#      - Incremento de Receita

# %%
df9 = X_test[cols_selected_boruta_full]

# %%
#rescale
df9['sales'] = np.expm1(df9['sales'])
df9['predictions'] = np.expm1(yhat_xgb_tuned)

# %% [markdown]
# ## 9.1. Business Performance

# %%
# sum of predictions
df91 = df9[['store','predictions']].groupby('store').sum().reset_index()

# MAE and MAPE
df9_aux1 = df9[['store','sales','predictions']].groupby('store').apply(lambda x: mean_absolute_error(x['sales'],x['predictions'])).reset_index().rename(columns={0:'MAE'})

df9_aux2 = df9[['store','sales','predictions']].groupby('store').apply(lambda x: mean_absolute_percentage_error(x['sales'],x['predictions'])).reset_index().rename(columns={0:'MAPE'})

# %%
# Merge 
df9_aux3 = pd.merge(df9_aux1, df9_aux2, how='inner', on='store')
df92 = pd.merge(df91, df9_aux3, how='inner', on='store')

#Scenarios
df92['worst_scenario'] = df92['predictions'] - df92['MAE']
df92['best_scenario'] = df92['predictions'] + df92['MAE']

#order columns
df92 = df92[['store', 'predictions','worst_scenario', 'best_scenario', 'MAE', 'MAPE']]

# %%
df92.sort_values('MAPE', ascending=False).head().reset_index(drop=True)
# Out:
#    store  predictions  worst_scenario  best_scenario     MAE  MAPE
# 0    292    104725.26       101399.44      108051.08 3325.82  0.55
# 1    909    240319.56       232701.08      247938.05 7618.49  0.52
# 2    876    204793.42       200941.93      208644.92 3851.49  0.29
# 3    595    390274.06       386518.96      394029.17 3755.11  0.26
# 4    722    342284.38       340571.28      343997.47 1713.09  0.23

# %%
plt.figure(figsize=(12,7))

sns.scatterplot(x='store', y='MAPE', data=df92).set_title('MAPE by store');

# %% [markdown]
# ## 9.2. Total Performance

# %%
# Total predicted
df9['predictions'].sum()
# Out:
# 283814370.0

# %%
df93 = df92[['predictions', 'worst_scenario', 'best_scenario']].apply(lambda x: np.sum(x), axis=0).reset_index().rename(columns={'index':'Scenario', 0:'Values'})
df93['Values'] = df93['Values'].map('$ {:,.2f}'.format)
df93
# Out:
#          Scenario            Values
# 0     predictions  $ 283,814,336.00
# 1  worst_scenario  $ 283,127,073.91
# 2   best_scenario  $ 284,501,608.23

# %% [markdown]
# ## 9.3. ML Performance

# %%
df9['error'] = df9['sales'] - df9['predictions']
df9['error_rate'] = df9['predictions'] / df9['sales']

# %%
plt.subplot(2,2,1)
sns.lineplot(x='date',y='sales', data=df9, label='SALES')
sns.lineplot(x='date',y='predictions', data=df9, label='PREDICTIONS')

plt.subplot(2,2,2)
sns.lineplot(x='date',y='error_rate', data=df9)
plt.axhline(1 , linestyle = '--')

plt.subplot(2,2,3)
sns.distplot(df9['error'])

plt.subplot(2,2,4)
sns.scatterplot(df9['predictions'],df9['error']);
